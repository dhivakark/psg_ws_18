# %% [markdown]
# # Basic Image Processing
#
# Dhivakar Kanagaraj & Senthil Palanisamy

# %% [markdown]
# # Image Representation
# * Images are Matrices
# * Intensity level 0 - 255

# %%
import cv2
import matplotlib.pyplot as plt
image = cv2.imread('data/tyrion.jpg', 0)

# Draw the image and show the matrix
print(image[:10, :10])
plt.imshow(image, 'gray')
plt.show()
# Out:
# [[194 194 192 195 193 191 191 190 190 188]
#  [192 194 190 194 188 191 189 190 190 190]
#  [191 191 191 191 191 190 190 188 189 188]
#  [192 192 191 192 190 190 190 190 190 188]
#  [192 191 189 190 191 189 189 188 188 189]
#  [191 192 189 190 188 188 188 189 188 188]
#  [191 191 191 189 191 188 189 188 190 189]
#  [191 191 190 190 187 189 187 189 188 190]
#  [192 190 189 189 188 188 187 190 189 190]
#  [192 190 190 189 188 189 188 188 189 189]]

# %% [markdown]
# # Color Images
# * 3 Channel
# <img src="files/rgb_exp.jpg">

# %%
image = cv2.imread('data/cersei.jpg')

# Draw the image and show the matrix
print('Red ->\n', image[:10, :10, 0], )
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# Red ->
#  [[209 209 210 211 212 213 214 214 215 216]
#  [208 209 210 211 212 213 213 214 215 215]
#  [208 208 209 210 211 212 212 213 214 214]
#  [207 207 208 209 210 211 212 212 213 214]
#  [206 206 207 208 209 210 211 211 212 213]
#  [206 206 207 208 209 210 211 211 212 213]
#  [208 208 209 210 211 212 213 213 214 215]
#  [208 208 209 210 211 212 213 213 214 215]
#  [207 208 209 210 211 212 212 213 214 214]
#  [207 208 208 209 210 211 212 212 214 214]]

# %% [markdown]
# # Transparant Images
# * Extra channel (Totally 4 channels)
# * Alpha Channel

# %% [markdown]
# # Color Spaces and Color Conversion
# * RGB
# * HSV
# * HSL

# %% [markdown]
# # Basic Notions
# * Brightness
# * Contrast

# %% [markdown]
# # Brightness
# * Addition of Scalar to the Matrix

# %%
image = cv2.imread('data/tyrion.jpg', 0)
bright_image = image + 20

# Draw the image and show the matrix
plt.imshow(image, 'gray')
plt.imshow(bright_image, 'gray')
plt.show()

# %% [markdown]
# # Histogram
# * N bins - Can be defined to anything (e.g, Equal to the number of intensity levels)
# * Number of pixel having each intesity level
# <img src="files/histogram.png">

# %% [markdown]
# # Contrast Stretching / Histogram Equivalization

# %% [markdown]
# # Thresholding

# %% [markdown]
# # Masking

# %% [markdown]
# # Object Localization based on Color

# %% [markdown]
# # Morphological operations
# * Erosion
# * Dilation
# * Closing
# * Opening

# %% [markdown]
# # Contours

# %% [markdown]
# # Convolution
# * A very common operation in computer vision"
# from IPython.display import HTML, display
# display(HTML("<table><tr><td><img src='files/conv1.gif'></td><td><img src='files/conv2.gif'></td></tr></table>"))

# %% [markdown]
# * Smoothing using convolution
# * Smoothing removes noise ( Reduce the variance of the pixel intensity distribution)
# * Different types of smoothing are avaialable
# * Gaussian, Average, Median

# %% [markdown]
# from IPython.display import HTML, display
# display(HTML("<table><tr><td><img src='files/median_filter.jpg'></td><td><img src='files/average_filter.png'></td></tr><tr><td><img src='files/weighted_average_filter.png'></td><td><img src='files/gaussian_kernel.png'></td></tr></table>"))
#
# from IPython.display import Image
# Image(filename='files/median_filter.jpg')
# Image(filename='files/average_filter.png')
# Image(filename='files/weighted_average_filter.png')

# %%
import matplotlib, cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

img = cv2.imread('data/opencv_numpy/lena_noisy.png')
plt.figure(figsize=(10,10))
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
img_blur_small = cv2.GaussianBlur(img, (5,5), 0)
plt.figure(figsize=(10,10))
plt.imshow(cv2.cvtColor(img_blur_small, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # Filtering / Smoothing

# %% [markdown]
# # Filtering

# %% [markdown]
# *what is an edge?
# *How can we spot an edge?
# display(HTML("<table><tr><td><img src='files/gradients/derivative.png'></td><td><img src='files/gradients/gradient.png'></td></tr><tr><td><img src='files/gradients/fx,fy.png'></td><td><img src='files/gradients/discrete_gradient.png'></td></tr></table>"))

# %% [markdown]
# # Image Gradients

# %% [markdown]
# from IPython.display import HTML, display
# display(HTML("<table><tr><td><img src='files/gradients/derivative.png'></td><td><img src='files/gradients/gradient.png'></td></tr><tr><td><img src='files/gradients/fx,fy.png'></td><td><img src='files/gradients/discrete_gradient.png'></td></tr></table>"))

# %% [markdown]
# from IPython.display import HTML, display
# display(HTML("<table><tr><td><img src='files/gradients/derivative.png'></td><td><img src='files/gradients/gradient.png'></td></tr><tr><td><img src='files/gradients/fx,fy.png'></td><td><img src='files/gradients/discrete_gradient.png'></td></tr></table>"))

# %% [markdown]
# # Edge detectors

# %% [markdown]
# # Keypoints & Features

# %% [markdown]
# # Projective Transformation

# %% [markdown]
# # Template Matching
